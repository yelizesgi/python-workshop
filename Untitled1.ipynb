# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Çift tirnak yazdim")
# Out:
# Çift tirnak yazdim

# %%
print('''uc tirnak ile yazdim''')
# Out:
# uc tirnak ile yazdim

# %%
print("I'm great")
# Out:
# I'm great

# %%
print('"hi" he said')
# Out:
# "hi" he said

# %%
print(''"Don't do it" said the manager'')
# Out:
#   File "<ipython-input-6-d33a20f0d809>", line 1
#     print('"Don't do it" said the manager')
#                 ^
# SyntaxError: invalid syntax

# %%
print(''"Don't do it" said the manager'')
# Out:
#   File "<ipython-input-7-32dd922c0bbc>", line 1
#     print(''"Don't do it" said the manager'')
#                           ^
# SyntaxError: invalid syntax

# %%
print('''Don't do it" said the manager''')
# Out:
# Don't do it" said the manager

# %%
print('I\'m great')
# Out:
# I'm great

# %%
print("\"don't do it\" said the manager")
# Out:
# "don't do it" said the manager

# %%
print('bu benim cumlem \nbu ikinci satir')
# Out:
# bu benim cumlem
# bu ikinci satir

# %%
print('by benim cumlem \tbu ikinci satir')
# Out:
# by benim cumlem 	bu ikinci satir
