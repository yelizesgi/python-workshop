# %%
school= "clarusway"

# %%
school
# Out:
# 'clarusway'

# %%
deneme1= "bir"
deneme2= "iki"
deneme3= "üç"
print(deneme1)
print(deneme2)
print(deneme3)
# Out:
# bir
# iki
# üç

# %%
okul= "clarusway"

# %%
okul
# Out:
# 'clarusway'

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               break               for                 not
# None                class               from                or
# True                continue            global              pass
# __peg_parser__      def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield

# %%
_okul= "clarusway"

# %%
5degisken= 64
# Out:
#   File "<ipython-input-15-2e51a2656f11>", line 1
#     5degisken= 64
#      ^
# SyntaxError: invalid syntax

# %%
isim soyisim= "ali güzel"
# Out:
#   File "<ipython-input-16-21afe50389db>", line 1
#     isim soyisim= "ali güzel"
#          ^
# SyntaxError: invalid syntax

# %%
variable= "değişken"

# %%
isim_soyisim= "ali güzel"

# %%
degisken= "bu bir string"
print(degisken)
# Out:
# bu bir string

# %%
degisken= 5
print(degisken)
# Out:
# 5

# %%
x= y= z= "same"
print(x)
print(y)
print(z)
# Out:
# same
# same
# same

# %%
january= march= may= july= august= october= december=  31
february= 28
april= june= september= november= 30
print(january,february,march,april,may,june,july,august,september,october,november,december )
# Out:
# 31 28 31 30 31 30 31 31 30 31 30 31

# %%
ali= None

# %%
print(ali)
# Out:
# None

# %%
ali

# %%
a, b, c = 5, 7, 9

# %%
print(a,b,c)
# Out:
# 5 7 9

# %%
a= "clarusway"
type(a)
# Out:
# str

# %%
sehir= "35"
type(sehir)
# Out:
# str

# %%
sayi1= 40
type(sayi1)
# Out:
# int

# %%
a= 5.7
type(a)
# Out:
# float

# %%
b= True
type(b)
# Out:
# bool

# %%
a= 123
type(a)
# Out:
# int

# %%
str(a)
# Out:
# '123'

# %%
str_a= str(a)

# %%
type(str_a)
# Out:
# str

# %%
pi=3.14
converted_pi= str(pi)
print(converted_pi)
print(type(converted_pi))
# Out:
# 3.14
# <class 'str'>

# %%
a= 1.23

# %%
type(a)
# Out:
# float

# %%
int(a)
# Out:
# 1

# %%
int(234.987)
# Out:
# 234

# %%
tamsayi= 7
type(a)
# Out:
# float

# %%
float(tamsayi)
# Out:
# 7.0

# %%
x= 39
v= "11"
y= "2.5"
z= "I am at_"
print(x-int(v))
print(x-float(y))
print(z+str(x))
# Out:
# 28
# 36.5
# I am at_39

# %%
5 + 3
# Out:
# 8

# %%
5 + 3.0
# Out:
# 8.0
