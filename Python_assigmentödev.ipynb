# %%
baslangic_yatirimi = 1000
kar_orani = 1.07
gun_sayi = 7
birinci_gun = 1000
ikinci_gun = birinci_gun * 1.07
ucuncu_gun = ikinci_gun * 1.07
dorduncu_gun = ucuncu_gun * 1.07
besinci_gun = dorduncu_gun * 1.07
altinci_gun = besinci_gun * 1.07
yedinci_gun = altinci_gun * 1.07 
STM = yedinci_gun
print(STM)
# Out:
# 1500.7303518490005
