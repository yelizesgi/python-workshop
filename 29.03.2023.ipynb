# %%
empty_dict1 = {}
empty_dict2 = dict()
print(type(empty_dict1))
# Out:
# <class 'dict'>

# %%
state_capitals = {'Arkansas' : 'Little Rock',
                  'Colorado' : 'Denver',
                  'California' : 'Sacramento',
                  'Georgia' : 'Atlanta'
                  }
print(state_capitals)
# Out:
# {'Arkansas': 'Little Rock', 'Colorado': 'Denver', 'California': 'Sacramento', 'Georgia': 'Atlanta'}

# %%
print(state_capitals['Colorado'])
# Out:
# Denver

# %%
state_capitals['Virgina'] = 'Richmond'
print(state_capitals)
# Out:
# {'Arkansas': 'Little Rock', 'Colorado': 'Denver', 'California': 'Sacramento', 'Georgia': 'Atlanta', 'Virgina': 'Richmond'}

# %%
#The key should be unique and an imutable object

# %%
sozluk = {'ali' : 25, 'veli': 30, 'ayse' : 35}

# %%
sozluk = {'ali' : 25, 'veli' : 30, 'ayse' : 35, 'ali' : 40}

# %%
sozluk
# Out:
# {'ali': 40, 'veli': 30, 'ayse': 35}

# %%
sozluk = {'ali': [30,4,68], 'veli': 30, 'ayse': True}
sozluk
# Out:
# {'ali': [30, 4, 68], 'veli': 30, 'ayse': True}

# %%
sozluk = {5: 'mehmet', 7 : 'ahmet', 9 : 'fatma'}
sozluk
# Out:
# {5: 'mehmet', 7: 'ahmet', 9: 'fatma'}

# %%
sozluk = {(1,2,3): 'mehmet', 7 : 'ahmet', 9: 'fatma'}
sozluk
# Out:
# {(1, 2, 3): 'mehmet', 7: 'ahmet', 9: 'fatma'}

# %%
sozluk = {{'ali' : 25, 'veli': 30, 'ayse' : 35}: 'mehmet', 7 : 'ahmet', 9: 'fatma'}#keyler kesinlikle değiştirilemez ögelerden oluşur
sozluk
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-4663837117a1> in <cell line: 1>()
# ----> 1 sozluk = {{'ali' : 25, 'veli': 30, 'ayse' : 35}: 'mehmet', 7 : 'ahmet', 9: 'fatma'}
#       2 sozluk
#
# TypeError: unhashable type: 'dict'

# %%
text = 'abcde'

# %%
text.replace('cd', 'klm')#orjinal text i değiştirmez
# Out:
# 'abklme'

# %%
text
# Out:
# 'abcde'

# %% [markdown]
# dict() function

# %%
dict(ali = 25, mehmet = 30, fatma = 35)
# Out:
# {'ali': 25, 'mehmet': 30, 'fatma': 35}

# %%
dict([('ali', 25), ('mehmet', 30), ('fatma', 35)])
# Out:
# {'ali': 25, 'mehmet': 30, 'fatma': 35}

# %%
dict(25 = 'ali', mehmet = 30, fatma = 35)#sayıya string atanmaz
# Out:
#   File "<ipython-input-16-bbf03c7f86d4>", line 1
#     dict(25 = 'ali', mehmet = 30, fatma = 35)
#          ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
dict(ali = (25,30,35,40), mehmet = 30, fatma = 35)
# Out:
# {'ali': (25, 30, 35, 40), 'mehmet': 30, 'fatma': 35}

# %%
sozluk = {'ali' : 25, 'veli': 30, 'ayse' : 35}
sozluk['ali']
# Out:
# 25

# %%
sozluk['mahmut'] = 55
sozluk
# Out:
# {'ali': 25, 'veli': 30, 'ayse': 35, 'mahmut': 55}

# %%
mix_values = {'animal':('dog','cat'),#tuple type
			'planet': ['Neptun', 'Saturn', 'Jupiter'],#list type
			'number': 40,#int type
			'pi':3.14,#float type
			'is_good': True}#bool type
mix_keys = {22:'integer',
		1.2:'float',
		True:'boolean',
		'key':'string'}

# %%
my_family = {'isim1' : 'Murat', 'isim2' : 'Yeliz', 'isim3' : 'M.Efe', 'isim4' : 'Melek'}
my_family
# Out:
# {'isim1': 'Murat', 'isim2': 'Yeliz', 'isim3': 'M.Efe', 'isim4': 'Melek'}

# %%
sozluk['veli']
# Out:
# 30

# %%
sozluk['veli'] = 25
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': 55}

# %%
sozluk.get('ali')
# Out:
# 25

# %%
sozluk.get('hasan')#get değeri hata değeri vermez içerik dict olmasa bile

# %%
sozluk['hasan']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-978a1e7dd55c> in <cell line: 1>()
# ----> 1 sozluk['hasan']
#
# KeyError: 'hasan'

# %%
sozluk.get('hasan', 'Kardesim duzgun bir deger yaz, oyle bir deger yok')
# Out:
# 'Kardesim duzgun bir deger yaz, oyle bir deger yok'

# %%
my_family['isim5'] = 'Zümra'
my_family
# Out:
# {'isim1': 'Murat',
#  'isim2': 'Yeliz',
#  'isim3': 'M.Efe',
#  'isim4': 'Melek',
#  'isim5': 'Zümra'}

# %%
sozluk['hasan'] = 77
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': 55, 'hasan': 77}

# %%
dict(ad =  'Yeliz', yer = 'İstanbul', meslek = 'FrontEnd')
# Out:
# {'ad': 'Yeliz', 'yer': 'İstanbul', 'meslek': 'FrontEnd'}

# %%
dict([('ad', 'Yeliz'), ('yer','İstanbul'), ('Meslek', 'FrontEnd'), ('ad', 'Murat')])
# Out:
# {'ad': 'Murat', 'yer': 'İstanbul', 'Meslek': 'FrontEnd'}

# %%
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': 55, 'hasan': 77}

# %%
sozluk.items()
# Out:
# dict_items([('ali', 25), ('veli', 25), ('ayse', 35), ('mahmut', 55), ('hasan', 77)])

# %%
sozluk.keys()
# Out:
# dict_keys(['ali', 'veli', 'ayse', 'mahmut', 'hasan'])

# %%
type(sozluk.keys())
# Out:
# dict_keys

# %%
keyler = list(sozluk.keys())
keyler
# Out:
# ['ali', 'veli', 'ayse', 'mahmut', 'hasan']

# %%
keyler[0]
# Out:
# 'ali'

# %%
sozluk.values()
# Out:
# dict_values([25, 25, 35, 55, 77])

# %%
my_family.items()
# Out:
# dict_items([('isim1', 'Murat'), ('isim2', 'Yeliz'), ('isim3', 'M.Efe'), ('isim4', 'Melek'), ('isim5', 'Zümra')])

# %%
my_family.keys()
# Out:
# dict_keys(['isim1', 'isim2', 'isim3', 'isim4', 'isim5'])

# %%
my_family.values()
# Out:
# dict_values(['Murat', 'Yeliz', 'M.Efe', 'Melek', 'Zümra'])

# %%
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': 55, 'hasan': 77}

# %%
sozluk.update({'kemal': '21'})
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': 55, 'hasan': 77, 'kemal': '21'}

# %%
kelime = 'abcdefg'
listem = list(kelime)
listem
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
del listem[2]
listem
# Out:
# ['a', 'b', 'd', 'e', 'f', 'g']

# %%
del sozluk['hasan']
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': 55, 'kemal': '21'}

# %%
del my_family['isim5']
my_family
# Out:
# {'isim1': 'Murat', 'isim2': 'Yeliz', 'isim3': 'M.Efe', 'isim4': 'Melek'}

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               break               for                 not
# None                class               from                or
# True                continue            global              pass
# __peg_parser__      def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield

# %%
sozluk['mahmut'] = None
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': None, 'kemal': '21'}

# %%
sozluk['mahmut'] = [25,76]
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': [25, 76], 'kemal': '21'}

# %%
sozluk['mahmut']
# Out:
# [25, 76]

# %%
sozluk['mahmut'][1]
# Out:
# 76

# %%
sozluk['mahmut'][1] = 45
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': [25, 45], 'kemal': '21'}

# %%
 del sozluk['mahmut'][1]
 sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': [25], 'kemal': '21'}

# %%
listem.pop()
listem
# Out:
# ['a', 'b', 'd', 'e', 'f']

# %%
listem.pop(0)
listem
# Out:
# ['b', 'd', 'e', 'f']

# %%
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'mahmut': [25], 'kemal': '21'}

# %%
sozluk.pop()#key lazım
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-663542e6dade> in <cell line: 1>()
# ----> 1 sozluk.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
sozluk.pop('mahmut')
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35, 'kemal': '21'}

# %%
sozluk.pop('mahmut', 'Bulamadım ki sileyim')
# Out:
# 'Bulamadım ki sileyim'

# %%
sozluk.popitem()
# Out:
# ('kemal', '21')

# %%
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35}

# %%
listem
# Out:
# ['b', 'd', 'e', 'f']

# %%
'b' in listem
# Out:
# True

# %%
'g' in listem
# Out:
# False

# %%
sozluk
# Out:
# {'ali': 25, 'veli': 25, 'ayse': 35}

# %%
'ali' in sozluk
# Out:
# True

# %%
25 in sozluk.values()
# Out:
# True

# %%
('ali' ,25) in sozluk.items()
# Out:
# True

# %%
my_family
# Out:
# {'isim1': 'Murat', 'isim2': 'Yeliz', 'isim3': 'M.Efe', 'isim4': 'Melek'}

# %%
'isim4' in my_family
# Out:
# True

# %%
school_records={
	'personal_info':
		{'kid':{'tom':{'class':'intermediate', 'age':10},
			'sue':{'class':'elemantary', 'age':8}
			},
		'teen':{'joseph':{'class':'college', 'age':19},
			'marry':{'class':'high school', 'age':16}
			},
		},
}
print(school_records['personal_info']['teen']['marry']['age'])
# Out:
# 16

# %%
school_records={
	'personal_info':
		{'kid':{'tom':{'class':'intermediate', 'age':10},
			'sue':{'class':'elemantary', 'age':8}
			},
		'teen':{'joseph':{'class':'college', 'age':19},
			'marry':{'class':'high school', 'age':16}
			},
		},
	'grades_info':
		{'kid':{'tom':{'math':88, 'speech':69},
			'sue':{'math':90, 'speech':81}
			},
		'teen':{'joseph':{'coding':80, 'math':89},
			'marry':{'coding':70, 'math':96}
			},
		}
}
print(school_records['grades_info']['teen']['joseph'])
# Out:
# {'coding': 80, 'math': 89}

# %%
print(school_records['grades_info']['teen']['joseph'])

# %%
list(school_records['grades_info']['teen']['joseph'].items())
# Out:
# [('coding', 80), ('math', 89)]

# %%
harf = ['a','b','c']
sayi = [1,2,3]

# %%
list(zip(harf,sayi))

# %%
dict(zip(harf,sayi))
# Out:
# {'a': 1, 'b': 2, 'c': 3}
