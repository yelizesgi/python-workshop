# %%
text= "Clarusway"
text[2:8]
# Out:
# 'aruswa'

# %%
text[4:7]
# Out:
# 'usw'

# %%
text[6:]
# Out:
# 'way'

# %%
text[0:6]
# Out:
# 'Clarus'

# %%
text[:6]
# Out:
# 'Clarus'

# %%
text="Clarusway"

# %%
text[1:8]
# Out:
# 'laruswa'

# %%
text[1:8:2]
# Out:
# 'lrsa'

# %%
text[1::3]
# Out:
# 'lua'

# %%
text[::2]
# Out:
# 'Cauwy'

# %%
text[5:1]
# Out:
# ''

# %%
text[5:1:-1]
# Out:
# 'sura'

# %%
text[5:1:-2]
# Out:
# 'sr'

# %%
text[::-1]
# Out:
# 'yawsuralC'

# %%
text= "kayak"
text==text[::-1]
# Out:
# True

# %%
yeni_text="abcde"
yeni_text==yeni_text[::-1]
# Out:
# False

# %%
yeni_text[::-1]
# Out:
# 'edcba'

# %%
text="Clarusway"

# %%
text[8]
# Out:
# 'y'

# %%
text[-1]
# Out:
# 'y'

# %%
text[8]==text[-1]
# Out:
# True

# %%
text[:-3:-1]
# Out:
# 'ya'

# %%
text[-3::-1]
# Out:
# 'wsuralC'

# %%
"a"+ "b"
# Out:
# 'ab'

# %%
text
# Out:
# 'Clarusway'

# %%
text[:4] + text[-3:]
# Out:
# 'Clarway'

# %%
text[:5] + "k" + text[-3:]
# Out:
# 'Clarukway'

# %%
len(text)#karakter sayısı
# Out:
# 9

# %%
print(text, "kelimesinin uzunlugu", len(text), "harften olusur")
# Out:
# Clarusway kelimesinin uzunlugu 9 harften olusur

# %%
text
# Out:
# 4

# %%
text= "Clarusway"
len(text)//2
# Out:
# 4

# %%
text[0]+ text[(len(text)//2)] + text[-1]
# Out:
# 'Cuy'

# %%
print(text)
# Out:
# Clarusway

# %%
print(*text)
# Out:
# C l a r u s w a y

# %%
a= 5
a= a+1
a
# Out:
# 6

# %%
a+=1
a
# Out:
# 7

# %% [markdown]
# %s string
# %d integers
# %f Floating

# %%
name= "Yeliz"
print("Merhaba, %s" %name)
# Out:
# Merhaba, Yeliz

# %%
name= "Yeliz"
age= 33
meslek = "FrontEnd"
print("Merhaba, ismin %s Yeliz %d mesleğin ise %s" % (name,age,meslek))
# Out:
# Merhaba, ismin Yeliz Yeliz 33 mesleğin ise FrontEnd

# %%
name= "Yeliz"
age= 33
meslek = "FrontEnd"
("Merhaba, ismin {} yasin {}  mesleğin ise {}".format(name,age,meslek))
# Out:
# 'Merhaba, ismin Yeliz yasin 33  mesleğin ise FrontEnd'

# %%
"Merhaba, ismin {0} yasin {1}  mesleğin ise {2}".format(name,age,meslek)
# Out:
# 'Merhaba, ismin Yeliz yasin 33  mesleğin ise FrontEnd'

# %% [markdown]
# positional

# %%
"Merhaba, ismin {a} yasin {b}  mesleğin ise {c}".format(a=name,b=age,c=meslek)
# Out:
# 'Merhaba, ismin Yeliz yasin 33  mesleğin ise FrontEnd'

# %% [markdown]
# keywords positional

# %%
"Merhaba, ismin {} yasin {b}  mesleğin ise {c}".format(name,b=age,c=meslek)
# Out:
# 'Merhaba, ismin Yeliz yasin 33  mesleğin ise FrontEnd'

# %%
"Merhaba, ismin {} yasin {}  mesleğin ise {}".format(b=age,c=meslek,name)
# Out:
#   File "<ipython-input-70-8d6439839456>", line 1
#     "Merhaba, ismin {} yasin {}  mesleğin ise {}".format(b=age,c=meslek,name)
#                                                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
taban=6
yukseklik= 4
"burada hesaplama gosterecegim{}".format(taban*yukseklik/2)
# Out:
# 'burada hesaplama gosterecegim12.0'

# %%
f"Meerhaba benim adım {name} yasim {age} meslegim{meslek}"
# Out:
# 'Meerhaba benim adım Yeliz yasim 33 meslegimFrontEnd'

# %%
print(f"Meerhaba benim adım {name} yasim {age} meslegim{meslek}")
# Out:
# Meerhaba benim adım Yeliz yasim 33 meslegimFrontEnd

# %%
"Burada hesaplama yapiyorum {taban*yukseklik/2}"
# Out:
# 'Burada hesaplama yapiyorum {taban*yukseklik/2}'

# %%
name="MARIAM"
f"My name is {name.capitalize()}"
# Out:
# 'My name is Mariam'

# %%
f"saga hizalama {name:>20}"# name 20 karakterlik bir alanda hizala
# Out:
# 'saga hizalama               MARIAM'

# %%
f"saga hizalama {name:<20}"#sola hizalama
# Out:
# 'saga hizalama MARIAM              '

# %%
f"saga hizalama {name:^20}"#ortalama
# Out:
# 'saga hizalama        MARIAM       '

# %%
f"saga hizalama {name:*^20}"
# Out:
# 'saga hizalama *******MARIAM*******'

# %%
name= "Susan"#print(f"{name} is a {age} {gender} and she is
# a student at the {school}")
age="young"
gender="lady"
school="CLRWY IT universy"
print(f"{name} is a {age} {gender} and she is a student at the {school}")
# Out:
# Susan is a young lady and she is a student at the CLRWY IT universy
