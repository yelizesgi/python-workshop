# %%
text= "Clarusway"
text[:5]
# Out:
# 'Claru'

# %%
yeni_string= text[:5] + "k" + text[-3:]

# %%
text= " AaBbCc"
print(text.lower())
# Out:
#  aabbcc

# %%
text
# Out:
# ' AaBbCc'

# %%
text= text.lower()

# %%
text
# Out:
# ' aabbcc'

# %%
cumle= "In God We Trust"

# %%
cumle.lower()
# Out:
# 'in god we trust'

# %%
cumle
# Out:
# 'In God We Trust'

# %%
cumle= cumle.lower()

# %%
cumle
# Out:
# 'in god we trust'

# %%
"t" in cumle
# Out:
# True

# %%
"R" not in cumle
# Out:
# True

# %%
"trust" in cumle
# Out:
# True

# %%
text= "aabbcc"

# %%
text.startswith("a")
# Out:
# True

# %%
text.startswith("b",2)
# Out:
# True

# %%
"abcdeabcde".startswith("c",2,8)
# Out:
# True

# %%
text = "a b c d"
len(text)
# Out:
# 7

# %%
email = 'clarusway@clarusway.com is my e-mail adress'
email[10:32]
# Out:
# 'clarusway.com is my e-'

# %%
text= "abcdef"
text.startswith("b", -5)
# Out:
# True

# %%
text= "abcabcabc"#2 başladığı index numarası
text.find("ca")
# Out:
# 2

# %%
text.find("klm")
# Out:
# -1

# %%
text.rfind("a")
# Out:
# 6

# %%
text.index("ca")
# Out:
# 2

# %%
text = "ClaRusWay"

# %%
text.upper()
# Out:
# 'CLARUSWAY'

# %%
text.lower()
# Out:
# 'clarusway'

# %%
text.swapcase()
# Out:
# 'cLArUSwAY'

# %%
text
# Out:
# 'ClaRusWay'

# %%
text.replace("W", "***")
# Out:
# 'ClaRus***ay'

# %%
text.replace("W","***").lower().upper()
# Out:
# 'CLARUS***AY'

# %%
string= "Ben seneye yepyeni bir iste calisiyor olacağim"

# %%
string.title()
# Out:
# 'Ben Seneye Yepyeni Bir Iste Calisiyor Olacağim'

# %%
sentence = "I live and work in Virginia"

# %%
sentence.capitalize

# %%
text= "S0d0me and G0m0re"
text.replace("0","o")
# Out:
# 'Sodome and Gomore'

# %%
isim = "    Ali    "

# %%
isim.strip()
# Out:
# 'Ali'

# %%
meslek = "  \n   codder  \t  "

# %%
meslek.strip()#sağ ve soldaki boşlukları siler
# Out:
# 'codder'

# %%
meslek.rstrip()#sağ taraftaki boşlukları siler
# Out:
# '  \n   codder'

# %%
text = "abcdabcd"

# %%
text.strip("a")
# Out:
# 'bcdabcd'

# %%
text.strip("ab")
# Out:
# 'cdabcd'

# %%
text.strip("ba")
# Out:
# 'cdabcd'

# %%
text.strip("bad")
# Out:
# 'cdabc'

# %%
text = 'tyou can learn almost everything in pre-classz'

# %%
text.strip("tz").upper()
# Out:
# 'YOU CAN LEARN ALMOST EVERYTHING IN PRE-CLASS'

# %%
text = "In God wee Trust"

# %%
text.replace("ee", "e")
# Out:
# 'In God we Trust'
