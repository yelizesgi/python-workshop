# %% [markdown]
# 1. What is a correct syntax to output "Hello World" in Python?(Python'da "Merhaba Dünya" çıktısı almak için doğru sözdizimi nedir?)

# %%
echo ="Hello World"
print(echo)
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
echo "Hello World"
# Out:
#   File "<ipython-input-2-1c643a414f93>", line 1
#     echo "Hello World"
#          ^
# SyntaxError: invalid syntax

# %%
p("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9910aa52f2ea> in <module>
# ----> 1 p("Hello World")
#
# NameError: name 'p' is not defined

# %% [markdown]
# 2. How do you insert COMMENTS in Python code?(YORUMLARI Python koduna nasıl eklersiniz?)

# %%
/*This is a commennt*/
# Out:
#   File "<ipython-input-6-1f9f559e4b56>", line 1
#     *This(is, a, commennt*/)
#           ^
# SyntaxError: invalid syntax

# %%
//This is a comment

# %%
#This is a comment

# %% [markdown]
# 3. Which one is NOT a legal variable name?(Hangisi yasal bir değişken adı DEĞİLDİR?)

# %%
Myvar = "A"
my_var = "b"
_myvar = "c"
my-var = "d"
print(Myvar)
print(my_var)
print(_myvar)
print(my-var)
# Out:
#   File "<ipython-input-9-1b51aa797e4e>", line 4
#     my-var = "d"
#     ^
# SyntaxError: cannot assign to operator

# %% [markdown]
# 4. How do you create a variable with the numeric value 5?(Sayısal değeri 5 olan bir değişkeni nasıl yaratırsınız?)

# %%
x = 5
new = float(x)
print(new)
print(type(new))
# Out:
# 5.0
# <class 'float'>

# %%
Both the other answers are correct(Diğer iki cevap da doğru)

# %%
x = int(5)

# %% [markdown]
# 5. What is the correct file extension for Python files?(Python dosyaları için doğru dosya uzantısı nedir?)
# .pt
# .py
# .pyt
# .pyth

# %%
x = ".py"# Python dosya uzantısı

# %% [markdown]
# 6. How do you create a variable with the floating number 2.8?(Kayan sayı 2.8 ile bir değişkeni nasıl yaratırsınız?)
#
# x = 2.8
#
# x = float(2.8)

# %%
x = 2.8
y = float(2.8)
print(x,y)
# Out:
# 2.8 2.8

# %% [markdown]
# 7. What is the correct syntax to output the type of a variable or object in Python?(Python'da bir değişkenin veya nesnenin türünü çıkarmak için doğru sözdizimi nedir?)
#
# print(type(x))
#
# print(typeof x)
#
# print(typeof(x))
#
# print(typeOf(x))

# %%
x = "Hello"
print(type(x))
# Out:
# <class 'str'>

# %% [markdown]
# 8. Insert the missing part of the code below to output "Hello World".("Merhaba Dünya" çıktısını almak için aşağıdaki kodun eksik kısmını ekleyin.)

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 9. What is the output?

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %% [markdown]
# 10. What is the output?

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# 11. What is the output?

# %%
x = "Python"
y = "is"
z = "awesome"
print(x + " " + y + " " + z)
# Out:
# Python is awesome

# %% [markdown]
# 12. What is the output?

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %% [markdown]
# 13. What is the output?

# %%
x = '5'
y = "John"
print(x + y)
# Out:
# 5John

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %% [markdown]
# 14. Create a variable named 'carname' and assign the value 'Volvo' to it.(Carname adlı bir değişken oluşturun ve ona Volvo değerini atayın.)

# %%
        Carname = "Volvo"
        print(Carname)
# Out:
# Volvo

# %% [markdown]
# 15. The following code example would print the data type of x, what data type would that be?(Aşağıdaki kod örneği, x veri türünü yazdırır, bu hangi veri türü olur?)

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# 16. What is the data type of variables?(Değişkenlerin veri türü nedir)

# %%
x = 1
y = 2.8 
z = 1j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# 17. What is the data type of variables?(Değişkenlerin veri türü nedir)

# %%
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# 18. What is the data type of variables?(Değişkenlerin veri türü nedir)

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# 19. What is the data type of variables?(Değişkenlerin veri türü nedir)

# %%
x = 35e3
y = 12E4
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# 20. Import the random module, and display a random number between 1 and 9:(Rastgele modülü içe aktarın ve 1 ile 9 arasında rastgele bir sayı görüntüleyin:)

# %%
import random

print(random.randrange(1, 10))
# Out:
# 4

# %% [markdown]
# 21. Insert the correct syntax to convert x into a floating point number.(x'i kayan noktalı bir sayıya dönüştürmek için doğru sözdizimini ekleyin.)

# %%
x = 5
y = float(x)
y
# Out:
# 5.0
