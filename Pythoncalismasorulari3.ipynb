# %% [markdown]
# 1. What is the output?

# %%
no1 = 96
print(no1/48)
# Out:
# 2.0

# %% [markdown]
# 2. What is the output?

# %%
sayi = 9
print(sayi**2)
# Out:
# 81

# %% [markdown]
# 3. What is the output?

# %%
print(64**0.5)
# Out:
# 8.0

# %% [markdown]
# 4. What is the output?

# %%
print('yesterday I ate', 2, 'apples')
# Out:
# yesterday I ate 2 apples

# %% [markdown]
# 5. What is the output?

# %%
print('i', end = ' ')
print('will say', end = '  ')
print('i missed you', end = ' ')
print('to my mother')
# Out:
# i will say  i missed you to my mother

# %% [markdown]
# 6. What is the output?

# %%
print('smoking', 'is', 'slowly', 'kiling me', sep=' + ')
# Out:
# smoking + is + slowly + kiling me

# %% [markdown]
# 7. What is theoutput?

# %%
x = 5
print('value of x    : ', x)
x += 2
print('2 more of x   : ', x, '\n')
y = 10
print('value of y    : ', y)
y -= 2
print('2 minus y     : ', y, '\n')
z = 6
print('value of z    : ', z)
z *= 2
print('2 times z     : ', z, '\n')
# Out:
# value of x    :  5
# 2 more of x   :  7
#
# value of y    :  10
# 2 minus y     :  8
#
# value of z    :  6
# 2 times z     :  12

# %% [markdown]
# 8. What is the output?

# %%
print('C:\\november\number_expenditure.txt')
# Out:
# C:\november
# umber_expenditure.txt

# %% [markdown]
# 9. What is the output?

# %%
print('one', 'two', 'three', sep ='\t')
# Out:
# one	two	three

# %% [markdown]
# 10. What is the output?

# %%
#print('we', '\bare', '\united')

# %% [markdown]
# 11. What is the output?

# %%
logic = True and False or not False or False
print(logic)
# Out:
# True

# %% [markdown]
# 12. What is the output?

# %%
print(1 and 'I am doing good!')
# Out:
# I am doing good!

# %% [markdown]
# 13. What is the output?

# %%
print([] and 'Hello World!')
# Out:
# []

# %%
print([] or 'Hello World!')
# Out:
# Hello World!

# %% [markdown]
# 14. Given the code below, use the correct logical operator in between the two expressions on line 1 in order for the final result to be False

# %%
result = ((25 % 7 + 10 / 2) % 3 == 0) and ((abs(-19) / 2 - 2) > 9)


print(result) #should return False
# Out:
# False

# %% [markdown]
# 15. Given the code below, use the correct logical operator in between the two expressions on line 1 in order for the final result to be True.

# %%
result = (min(pow(2, abs(3)), 9) == 3 ** 2 - 1) or (66 % 20 + 2 > 2 ** 3)
print(result) #should return True
# Out:
# True

# %% [markdown]
# 16. Given the code below, use the correct function on line 1 (for which the argument sits inside the parentheses) in order for the final result to be False.

# %%
result = bool((150 % (10 ** 2 / 2)))
print(result)#should return False
# Out:
# 0.0
