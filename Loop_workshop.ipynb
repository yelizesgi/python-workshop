# %% [markdown]
# Write a for loop that iterates over the x list and prints out all the elements of the list.
# (x listesi üzerinde yinelenen ve listenin tüm öğelerini yazdıran bir for döngüsü yazın.)

# %%
x = [10, 12, 13, 14, 17, 19, 21, 22, 25]
for i in x:
  print(i)
# Out:
# 10
# 12
# 13
# 14
# 17
# 19
# 21
# 22
# 25

# %% [markdown]
# Write a for loop that iterates over the x list and prints out the remainders of each element of the list divided by 3.
# x listesi üzerinde yinelenen ve listenin her bir öğesinin kalanını 3'e bölerek yazdıran bir for döngüsü yazın.

# %%
x = [10, 12, 13, 14, 17, 19, 21, 22, 25]
for i in x:
  print(i%3)
# Out:
# 1
# 0
# 1
# 2
# 2
# 1
# 0
# 1
# 1

# %% [markdown]
# Write a for loop that iterates over the x list and prints out all the elements of the list in reversed order and multiplied by 10.
# x listesi üzerinde yinelenen ve listenin tüm öğelerini ters sırayla ve 10 ile çarparak yazdıran bir for döngüsü yazın.

# %%
x = [10, 12, 13, 14, 17, 19, 21, 22, 25]
x.reverse()
for i in x:
  print(i*10)
# Out:
# 250
# 220
# 210
# 190
# 170
# 140
# 130
# 120
# 100

# %%
x = [10, 12, 13, 14, 17, 19, 21, 22, 25]
for i in sorted(x, reverse = True):
  print(i*10)
# Out:
# 250
# 220
# 210
# 190
# 170
# 140
# 130
# 120
# 100

# %% [markdown]
# Write a for loop that iterates over the x list and prints out all the elements of the list divided by 2 and the string Great job! after the list is exhausted
# x listesi üzerinde yinelenen ve listenin tüm öğelerini 2'ye bölerek ve Great job! dizesini yazdıran bir for döngüsü yazın. liste bittikten sonra

# %%
x = [10, 12, 13, 14, 17, 19, 21, 22, 25]
for i in x:
  print(i/2)
else:
  print('Great Job!')
# Out:
# 5.0
# 6.0
# 6.5
# 7.0
# 8.5
# 9.5
# 10.5
# 11.0
# 12.5
# Great Job!

# %% [markdown]
# Write a for loop that iterates over the x list and prints out the index of each element.
# x listesi üzerinde yinelenen ve her öğenin dizinini yazdıran bir for döngüsü yazın.

# %%
x = [10, 12, 13, 14, 17, 19, 21, 22, 25]
for i in x:
  print(f"{i} elemanın index {x.index(i)}")
# Out:
# 10 elemanın index 0
# 12 elemanın index 1
# 13 elemanın index 2
# 14 elemanın index 3
# 17 elemanın index 4
# 19 elemanın index 5
# 21 elemanın index 6
# 22 elemanın index 7
# 25 elemanın index 8

# %% [markdown]
# Write a while loop that prints out the value of x squared while x is less than or equal to 5. Be careful not to end up with an infinite loop!
# x küçük veya 5'e eşitken x karenin değerini yazdıran bir while döngüsü yazın. Sonsuz bir döngüye girmemeye dikkat edin!

# %%
x = 0
while x<=5:
  print(x**2)
  x +=1
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# Write a while loop that prints out the value of x times 10 while x is less than or equal to 4 and then prints out Done! when x becomes larger than 4. Be careful not to end up with an infinite loop!
# x çarpı 10'un değerini, x ise küçük veya eşittir 4'ü yazdıran ve ardından Bitti! çıktısını yazdıran bir while döngüsü yazın. x, 4'ten büyük olduğunda. Sonsuz bir döngüye girmemeye dikkat edin!

# %%
x = 0
while x<= 4:
  print(x*10)
  x +=1
else:
  print("done")
# Out:
# 0
# 10
# 20
# 30
# 40
# done

# %%
x = 0
while x <= 4:
  print(x*10)
  x += 1
print("done")
# Out:
# 0
# 10
# 20
# 30
# 40
# done

# %% [markdown]
# Write a while loop that prints out the value of x plus 10 while x is less than or equal to 15 and the remainder of x divided by 5 is 0. Be careful not to end up with an infinite loop!
# x'in 15'ten küçük veya eşit olduğu ve x'in 5'e bölümünden kalanın 0 olduğu durumda, x artı 10'un değerini yazdıran bir while döngüsü yazın. Sonsuz bir döngüye girmemeye dikkat edin!

# %%
x = 10
while x <= 15 and x % 5 == 0:
  print(x + 10)
  x += 1
# Out:
# 20

# %% [markdown]
# Write a while loop that prints out the absolute value of x while x is negative. Be careful not to end up with an infinite loop!
# x negatifken x'in mutlak değerini yazdıran bir while döngüsü yazın. Sonsuz bir döngüye girmemeye dikkat edin!

# %%
x = -7
while x<0:
  print(abs(x))
  x += 1
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# Write a while loop that prints out the value of x times y while x is greater than or equal to 5 and less than 10, and prints out the result of x divided by y when x becomes 10. Be careful not to end up with an infinite loop!
# x büyük veya eşit ve 10'dan küçükken x çarpı y'nin değerini ve x 10 olduğunda x bölü y'nin sonucunu yazdıran bir while döngüsü yazın. sonsuz döngü!

# %%
x = 5
y = 2
while x >= 5 and x < 10:
  print(x * y)
  x += 1
else:
  print(x/y)
# Out:
# 10
# 12
# 14
# 16
# 18
# 5.0

# %% [markdown]
# Write code that will iterate over the x list and multiply by 10 only the elements that are greater than 20 and print them out to the screen.
#
# Hint: use nesting!
# x listesi üzerinde yineleme yapacak ve sadece 20'den büyük elemanları 10 ile çarpacak ve ekrana yazdıracak bir kod yazın.
#
# İpucu: iç içe yerleştirmeyi kullanın!

# %%
x = [10, 12, 13, 14, 17, 19, 21, 22, 25]
for i in x:
  if i > 20:
    print(i*10)
# Out:
# 210
# 220
# 250

# %%
print([i*10 for i in x if i > 20])
# Out:
# [210, 220, 250]

# %% [markdown]
# Write code that will iterate over the x and y lists and multiply each element of x with each element of y, also printing the results to the screen.
#
# Hint: use nesting!
# x ve y listelerini yineleyecek ve x'in her bir öğesini y'nin her bir öğesiyle çarpacak ve ayrıca sonuçları ekrana yazdıracak bir kod yazın.
#
# İpucu: iç içe yerleştirmeyi kullanın!

# %%
x = [2, 4, 6]
y = [5, 10]
for i in x:
  for j in y:
    print(i*j)
# Out:
# 10
# 20
# 20
# 40
# 30
# 60

# %%
x = [2, 4, 6]
y = [5, 10]
print([i * j for i in x for j in y])
# Out:
# [10, 20, 20, 40, 30, 60]

# %% [markdown]
# Write code that will iterate over the x and y lists and multiply each element of x with each element of y that is less than 12, also printing the results to the screen.
#
# Hint: use nesting!
# x ve y listelerini yineleyecek ve x'in her bir öğesini 12'den küçük olan her bir y öğesiyle çarpacak ve sonuçları ekrana yazdıracak bir kod yazın.
#
# İpucu: iç içe yerleştirmeyi kullanın!

# %%
x = [2, 4, 6, 8]
y = [5, 10, 15, 20]
for i in x:
  for j in y:
    if j < 12:
     print(i*j)
# Out:
# 10
# 20
# 20
# 40
# 30
# 60
# 40
# 80

# %% [markdown]
# Write code that will iterate over the x and y lists and multiply each element of x that is greater than 5 with each element of y that is less than 12, also printing the results to the screen.
# x ve y listeleri üzerinde yineleme yapacak ve x'in 5'ten büyük her elemanını y'nin 12'den küçük her elemanıyla çarpacak ve ayrıca sonuçları ekrana yazdıracak bir kod yazın.

# %%
x = [2, 4, 6, 8]
y = [5, 10, 15, 20]
for i in x:
  if i > 5:
    for j in y:
      if j < 12:
        print(i*j)
# Out:
# 30
# 60
# 40
# 80

# %%
x = [2, 4, 6, 8]
y = [5, 10, 15, 20]

for i in x:
  for j in y:
    if (i > 5) & (j < 12):
      print(i * j)
# Out:
# 30
# 60
# 40
# 80

# %% [markdown]
# Write code that will iterate over the x and y lists and multiply each element of x with each element of y that is less than or equal to 10, also printing the results to the screen. For y's elements that are greater than 10, multiply each element of x with y squared.
# x ve y listeleri üzerinde yineleme yapacak ve x'in her bir öğesini y'nin 10'dan küçük veya ona eşit olan her bir öğesiyle çarpacak ve ayrıca sonuçları ekrana yazdıracak bir kod yazın. y'nin 10'dan büyük elemanları için, x'in her elemanını y'nin karesiyle çarp.

# %%
x = [2, 4, 6, 8]
y = [5, 10, 15, 20]
for i in x:
  for j in y:
    if j <= 10:
      print(i*j)
    else:
      print(i * j ** 2)
# Out:
# 10
# 20
# 450
# 800
# 20
# 40
# 900
# 1600
# 30
# 60
# 1350
# 2400
# 40
# 80
# 1800
# 3200

# %% [markdown]
# Write code that will print out each character in x doubled if that character is also inside y.

# %%
x = "cryptocurrency"
y = "blockchain"
for i in x:
  if i in y:
    print(i*2)
# Out:
# cc
# oo
# cc
# nn
# cc

# %% [markdown]
# Write code that will iterate over the range generated by range(9) and for each element that is between 3 and 7 inclusively print out the result of multiplying that element by the second element in the same range.
# range(9) tarafından oluşturulan aralık üzerinde yineleme yapacak bir kod yazın ve 3 ile 7 arasındaki her öğe için, o öğeyi aynı aralıktaki ikinci öğeyle çarpmanın sonucunu yazdırın.

# %%
my_range = range(9)

for i in my_range:
  if 3 <= i < 7:
    print(i * my_range[1])
# Out:
# 3
# 4
# 5
# 6

# %% [markdown]
# Write a while loop that prints out the value of x times 11 while x is less than or equal to 11.  When x becomes equal to 10, print out x is 10! Be careful not to end up with an infinite loop!
# x eşittir 11 iken x çarpı 11'in değerini yazdıran bir while döngüsü yazın. x 10'a eşit olduğunda, x eşittir 10'u yazdırın! Sonsuz bir döngüye girmemeye dikkat edin!

# %% [markdown]
# Insert a break statement where necessary in order to obtain the following result:
# Aşağıdaki sonucu elde etmek için gerektiğinde bir break ifadesi ekleyin:

# %% [markdown]
# Insert a break statement where necessary in order to obtain the following result:
# Aşağıdaki sonucu elde etmek için gerektiğinde bir break ifadesi ekleyin:
# # output expected
# 1
#
# 10
#
# 20
#
# 2
#
# 10

# %% [markdown]
# Insert a break statement where necessary in order to obtain the following result:
# Aşağıdaki sonucu elde etmek için gerektiğinde bir break ifadesi ekleyin:
# #expected output
# 1
#
# 1
#
# 100
#
# 10

# %% [markdown]
# Insert a continue statement where necessary in order to obtain the following result:
# Aşağıdaki sonucu elde etmek için gerektiğinde bir devam ifadesi ekleyin:
# #expected output
# 1
#
# 1
#
# 100
#
# 20
#
# 200
#
# 100
