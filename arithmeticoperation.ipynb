# %%
3+5
# Out:
# 8

# %%
"3" + "5"
# Out:
# '35'

# %%
3 * 5
# Out:
# 15

# %%
"abc" * 3
# Out:
# 'abcabcabc'

# %%
"3" + "abc"
# Out:
# '3abc'

# %%
print(11-7)
print(4 + 11.0)
print("11-7")
print("4"+ 4)
# Out:
# 4
# 15.0
# 11-7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-dcb2f1255d95> in <module>
#       2 print(4 + 11.0)
#       3 print("11-7")
# ----> 4 print("4"+ 4)
#
# TypeError: can only concatenate str (not "int") to str

# %%
num1, num2 = 81, 55
num3= num1 - num2
print(num3)
# Out:
# 26

# %%
r= 5
p= 3.14
area= p * (r**2)  
print(area)
# Out:
# 78.5

# %%
print(11%2)
print((4*5)/2)
# Out:
# 1
# 10.0

# %%
print(2**3)
print(3**2)
a= 2
b= 8
print((a*b) ** 0.5)
# Out:
# 8
# 9
# 4.0

# %%
5**0.5
# Out:
# 2.23606797749979

# %%
a = 5

# %%
3+5*2
# Out:
# 13

# %%
a=(1+1)**(4**(2/2*2)/2)
print(a)
# Out:
# 256.0

# %%
a= -3**2
print(a)
# Out:
# -9

# %%
(-3)**2
# Out:
# 9

# %%
a= 3
b= 4
c= ((3**2) + (4**2))**0.5
print(c)
# Out:
# 5.0

# %%
print(a,b,c)
# Out:
# 3 4 5.0

# %%
print(a,b,c, sep="----------->")
# Out:
# 3----------->4----------->5.0

# %%
print(a)
print(b)
print(c)
# Out:
# 3
# 4
# 5.0

# %%
print(a,end="bittiiii")
print(b)
print(c)
# Out:
# 3bittiiii4
# 5.0

# %%
bir= "ilk satir"
iki= "ikinci satir"
uc="ucuncu satir"
print(bir,iki,uc)
# Out:
# ilk satir ikinci satir ucuncu satir

# %%
print(bir,iki,uc, sep=" ")
# Out:
# ilk satir ikinci satir ucuncu satir

# %%
print(bir,iki,uc, sep="----bosluk---- ")
# Out:
# ilk satir----bosluk---- ikinci satir----bosluk---- ucuncu satir

# %%
print(bir,end="\n")
print(iki,end="\n")
print(uc,end="\n")
# Out:
# ilk satir
# ikinci satir
# ucuncu satir

# %%
print(bir,end="\n******")
print(iki,end="\n")
print(uc,end="\n")
# Out:
# ilk satir
# ******ikinci satir
# ucuncu satir

# %%
number=2021
text="we have reache"
print(text, number)
# Out:
# we have reache 2021

# %%
text1= "I bought"
text2= "kg. of apple this morning"
amount= 6
text3= text1 + " " + str(amount) + " " + text2
print(text1,text2,text3)
print("I bought",6,"kg. of apple this morning")
print("I bought " + "6" + " kg. of apple this morning")
print(text3)
# Out:
# I bought kg. of apple this morning I bought 6 kg. of apple this morning
# I bought 6 kg. of apple this morning
# I bought 6 kg. of apple this morning
# I bought 6 kg. of apple this morning

# %%
print("C:\\north pole\noise_penguis.txt")
print("--------")
print("first","second","third",sep="\t")
# Out:
# C:\north pole
# oise_penguis.txt
# --------
# first	second	third

# %%
print("C:\north pole\noise_penguis.txt")
print("--------")
print("first","second","third",sep="\t")
# Out:
# C:
# orth pole
# oise_penguis.txt
# --------
# first	second	third

# %%
print('Bu\gun\ben\neden\taskiye\bindim')
# Out:
# en
# indim

# %%
print('Bu\gun\\ben\\neden\\taskiye\\bindim')
# Out:
# Bu\gun\ben\neden\taskiye\bindim

# %%
print("we are", "\boosting", "our", "\brotherhood")
print('it\'s eesential to learn python\'s libraries in IT World')
# Out:
# rotherhood
# it's eesential to learn python's libraries in IT World

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True and True and True
# Out:
# False

# %%
True or False or False
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
1 and 1
# Out:
# 1

# %%
1 and 0
# Out:
# 0

# %%
bool("abcdeg")
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not "string"
# Out:
# False

# %%
bool_var= True and not True
print(bool_var)
# Out:
# False

# %%
True and False or not False or False
# Out:
# True

# %%
True and True and True
# Out:
# True

# %%
"string" and 5 and 6.2 #en son ki değeri döndürür hepsi True ise
# Out:
# 6.2

# %%
5 and 0 and False and "abcde"# False da ilk karşılaştığı False değerini döndürür
# Out:
# 0

# %%
False or False or False or True
# Out:
# True

# %%
False or "" or "False" or "35" or 45#ilk bulduğu True değerini yazar
# Out:
# 'False'

# %%
print(2 and 3)
# Out:
# 3

# %%
print(1 and 0)
# Out:
# 0

# %%
print(2 and "hello world")
print([] and "be happy!")
print(None and ())
# Out:
# hello world
# []
# None

# %%
print( 2 or 3)
# Out:
# 2

# %%
print( None or 1)
# Out:
# 1

# %%
print(2 or "hello world")
print([] or "be happy!")
print(None or ())
print({} or 0)
print({0} or False)
# Out:
# 2
# be happy!
# ()
# 0
# {0}
