# %%
listem = ["a", "b", "c", "d"]

# %%
type(listem)
# Out:
# list

# %%
word = "happy"

# %%
list(word)
# Out:
# ['h', 'a', 'p', 'p', 'y']

# %%
list("a b c")
# Out:
# ['a', ' ', 'b', ' ', 'c']

# %%
text = "Clarusway"
list(text)
# Out:
# ['C', 'l', 'a', 'r', 'u', 's', 'w', 'a', 'y']

# %%
[text]
# Out:
# ['Clarusway']

# %%
listem = [1,2,3]
len(listem)
# Out:
# 3

# %%
list(listem)
# Out:
# [1, 2, 3]

# %%
yeni= [listem]

# %%
len(yeni)
# Out:
# 1

# %%
a = [[1,2,3], ["ali", "ayse",],[True, False]]
len(a)
# Out:
# 3

# %%
list(a)
# Out:
# [[1, 2, 3], ['ali', 'ayse'], [True, False]]

# %%
liste_a= [a]

# %%
len(liste_a)
# Out:
# 1

# %%
string= "2023's perfect"
list(string)
# Out:
# ['2', '0', '2', '3', "'", 's', ' ', 'p', 'e', 'r', 'f', 'e', 'c', 't']

# %%
[string]
# Out:
# ["2023's perfect"]

# %%
list("1234")
# Out:
# ['1', '2', '3', '4']

# %%
listem = [[1,2,3], "bir string", 7.23, True]
len(listem)
# Out:
# 4

# %%
bos1 = []
len(bos1)
# Out:
# 0

# %%
bos2 = list()
len(bos2)
# Out:
# 0

# %%
numbers = [1,4,7]
numbers.append(9)
numbers.append("9")
print(numbers)
# Out:
# [1, 4, 7, 9, '9']

# %%
numbers.append(["a","b","c"])

# %%
print(numbers)
# Out:
# [1, 4, 7, 9, '9', ['a', 'b', 'c']]

# %%
numbers
# Out:
# (1, 2, 3, 4)

# %%
len(numbers)
# Out:
# 6

# %%
liste = []

# %%
liste = 1,2,3,4
yeni_liste= list(numbers)

# %%
yeni_liste.append([5,6,7])

# %%
yeni_liste
# Out:
# [1, 2, 3, 4, [5, 6, 7]]

# %%
listem = ["a", "b", "c", "d"]

# %%
listem.insert(3,12)

# %%
listem
# Out:
# ['a', 'b', 'c', 12, 'd']

# %%
liste = [1,2,3,4]
liste.insert(4,5)
print(liste)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers = [1,2,3,4,9, ["a", "b", "c"]]
numbers.remove(9)

# %%
numbers
# Out:
# [1, 2, 3, 4, ['a', 'b', 'c']]

# %%
 numbers.remove(["a", "b", "c"])

# %%
numbers
# Out:
# [1, 2, 3, 4]

# %%
listem = [1,2,3,4,2,3,4,3]

# %%
listem.remove(2)

# %%
listem
# Out:
# [1, 3, 4, 2, 3, 4, 3]

# %%
listem.pop()
# Out:
# 3

# %%
listem
# Out:
# [1, 3, 4, 2, 3, 4]

# %%
listem.pop(4)#index numarasına göre silme
# Out:
# 3

# %%
listem
# Out:
# [1, 3, 4, 2, 4]

# %%
yeni_listem = ["a", "b", "c","d"]

# %%
yeni_listem.remove("b")

# %%
yeni_listem
# Out:
# ['a', 'c', 'd']

# %%
yeni_listem.pop(1)
# Out:
# 'c'

# %%
yeni_listem
# Out:
# ['a', 'd']

# %%
listem = [2,7,3,0,5,7]

# %%
listem.sort()# verilen elemanları kalıcı olarak değiştirerek sıralar

# %%
listem
# Out:
# [0, 2, 3, 5, 7, 7]

# %%
listem.sort(reverse=True)#tersden sıralar

# %%
listem
# Out:
# [7, 7, 5, 3, 2, 0]

# %%
isimler.sort()

# %%
isimler
# Out:
# ['ali', 'ayşe', 'kemal', 'veli']

# %%
isimler.append("Zeki")

# %%
isimler
# Out:
# ['Zeki', 'ali', 'ayşe', 'kemal', 'veli', 'zeki', 'Zeki']

# %%
isimler.sort()

# %%
isimler
# Out:
# ['Zeki', 'ali', 'ayşe', 'kemal', 'veli', 'zeki']

# %%
ord("A")#ASCII değerini bulma
# Out:
# 65

# %%
chr(97)
# Out:
# 'a'

# %%
listem = [ 1, "x", 2.4, True]

# %%
listem.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-6c87b058e0a4> in <module>
# ----> 1 listem.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
list_1 = ["one", "four", "nine"]

# %%
list_1.sort()

# %%
list_1
# Out:
# ['four', 'nine', 'one']

# %%
list_2 = ["*-", "@", "False"]

# %%
list_2.sort()

# %%
list_2
# Out:
# ['*-', '@', 'False']

# %%
list_3 = [True, False]

# %%
list_3.sort()#0-1 e göre sıralar

# %%
list_3
# Out:
# [False, True]

# %%
list_4 = [[3], [44], [-12]]

# %%
list_4.sort()

# %%
list_4
# Out:
# [[-12], [3], [44]]

# %%
list_5 = [[1,3], [44,0], [-12,1]]#ilk elemanlara bakarak sıralar

# %%
list_5.sort()

# %%
list_5
# Out:
# [[-12, 1], [1, 3], [44, 0]]

# %%
isimler = ["ali", "ayşe", "kemal", "zeki"]

# %%
isimler = sorted(isimler)

# %%
isimler
# Out:
# ['ali', 'ayşe', 'kemal', 'zeki']

# %%
isimler = sorted(isimler,reverse=True)

# %%
isimler
# Out:
# ['zeki', 'kemal', 'ayşe', 'ali']

# %%
[1,2,3] + ["a", "b", "c"]
# Out:
# [1, 2, 3, 'a', 'b', 'c']

# %%
 ["a", "b", "c"]*3
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c']
